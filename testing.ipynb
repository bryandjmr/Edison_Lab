# %%
import sphere_class as s_class
import numpy as np

# %%
r = 0.05
good = s_class.sphere()
'''
#final test
p_theta1, p_phi1 = np.random.uniform(0,2*np.pi), np.random.uniform(0,np.pi)
p_theta2, p_phi2 = np.random.uniform(0,2*np.pi), np.random.uniform(0,np.pi)
v_theta1, v_phi1 = np.random.uniform(-1,1), np.random.uniform(-1,1)
v_theta2, v_phi2 = np.random.uniform(-1,1), np.random.uniform(-1,1)

a = [p_theta1, p_phi1]
b = [p_theta2, p_phi2]
v1 = [v_theta1, v_phi1]
v2 = [v_theta2, v_phi2]

'''

#theta and phi test
a,v1 = [0, 0], [np.pi/4, np.pi/8]
b,v2 = [np.pi/2, np.pi/4], [-np.pi/4, -np.pi/8]

#theta test
#a,v1 = [np.pi/2, np.pi/2], [-np.pi/4, 0]
#b,v2 = [0, np.pi/2], [np.pi/4, 0]


#phi test
#a,v1 = [0, 0], [0, np.pi/4]
#b,v2 = [0, np.pi/2], [0, -np.pi/4]

good.add_p(a,v1,r)
good.add_p(b,v2,r)

# %%
good.simulation(3)
# Out:
# Information: Simulation has started
# Time: 0
#  Position:
#  [[0.00000000e+00 0.00000000e+00 1.00000000e+00]
#  [4.32978028e-17 7.07106781e-01 7.07106781e-01]]
#
# Time: 0.00310144
# Position:
#  [[1.21792769e-03 2.96671110e-06 9.99999258e-01]
#  [1.72031463e-03 7.06242954e-01 7.07967464e-01]]
#
# Time: 0.12733722
# Position:
#  [[0.04973461 0.00499063 0.99875   ]
#  [0.06698306 0.66752631 0.74156719]]
#
# Time: 0.15384615
# Position:
#  [[0.05993827 0.00727782 0.99817555]
#  [0.0799306  0.65828775 0.74851075]]
#
# Time: 0.27018163
# Position:
#  [[0.10352575 0.02230396 0.99437667]
#  [0.13231588 0.61415544 0.77801389]]
#
# Time: 0.3030303
# Position:
#  [[0.11537256 0.02798908 0.99292788]
#  [0.1457365  0.60073405 0.78605309]]
#
# Time: 0.39441741
# Position:
#  [[0.14692596 0.04702793 0.98802891]
#  [0.17972309 0.56149583 0.80772646]]
#
# Time: 0.53726182
# Position:
#  [[0.19105137 0.08576885 0.97782569]
#  [0.2225286  0.49568572 0.83950979]]
#
# Time: 0.57142857
# Position:
# ...
